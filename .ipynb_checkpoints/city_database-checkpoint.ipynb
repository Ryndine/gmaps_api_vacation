# %%
from citipy import citipy
import numpy as np
import pandas as pd
import requests
import time
from datetime import datetime
from config import weather_api_key

# %% [markdown]
# ### Weather Data.

# %%
# Random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = list(zip(lats, lngs))

# %%
# Finding cities near the coordinates
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
# Check results
len(cities)
# Out:
# 735

# %%
# API Url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ### API call

# %%
# List of city data
city_data = []

# Print to logger
print("   Beginning Data Retrieval   ")
print("------------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("   Data Retrieval Complete   ")
print("-----------------------------")
# Out:
#    Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | sattahip
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | souillac
# Processing Record 4 of Set 1 | pacific grove
# Processing Record 5 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 1 | lorengau
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | mont-de-marsan
# Processing Record 9 of Set 1 | srivardhan
# Processing Record 10 of Set 1 | adrar
# Processing Record 11 of Set 1 | sabha
# Processing Record 12 of Set 1 | port-gentil
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | saskylakh
# Processing Record 15 of Set 1 | abu samrah
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | pisco
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | vao
# Processing Record 20 of Set 1 | hun
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | baruun-urt
# Processing Record 24 of Set 1 | pevek
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | paamiut
# Processing Record 28 of Set 1 | hami
# Processing Record 29 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 1 | harer
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | taoudenni
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | acapulco
# Processing Record 35 of Set 1 | puerto ayacucho
# Processing Record 36 of Set 1 | carnarvon
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | bethel
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | buchanan
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | torbay
# Processing Record 44 of Set 1 | te anau
# Processing Record 45 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 1 | masvingo
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | coquimbo
# Processing Record 50 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 2 | tyumentsevo
# Processing Record 2 of Set 2 | bengkulu
# Processing Record 3 of Set 2 | tuatapere
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | capreol
# Processing Record 6 of Set 2 | airai
# Processing Record 7 of Set 2 | oga
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | eidfjord
# Processing Record 10 of Set 2 | san pedro
# Processing Record 11 of Set 2 | aklavik
# Processing Record 12 of Set 2 | tasiilaq
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | khandyga
# Processing Record 15 of Set 2 | georgetown
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | iqaluit
# Processing Record 18 of Set 2 | crotone
# Processing Record 19 of Set 2 | leh
# Processing Record 20 of Set 2 | vanimo
# Processing Record 21 of Set 2 | havoysund
# Processing Record 22 of Set 2 | umm lajj
# Processing Record 23 of Set 2 | albany
# Processing Record 24 of Set 2 | ginda
# Processing Record 25 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 26 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 2 | faya
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | saint-philippe
# Processing Record 30 of Set 2 | salamanca
# Processing Record 31 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 2 | cockburn town
# Processing Record 33 of Set 2 | arman
# Processing Record 34 of Set 2 | shelopugino
# Processing Record 35 of Set 2 | new norfolk
# Processing Record 36 of Set 2 | mataura
# Processing Record 37 of Set 2 | conde
# Processing Record 38 of Set 2 | provideniya
# Processing Record 39 of Set 2 | dingle
# Processing Record 40 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 2 | toora-khem
# Processing Record 42 of Set 2 | san pedro de macoris
# Processing Record 43 of Set 2 | sayyan
# Processing Record 44 of Set 2 | kozhva
# Processing Record 45 of Set 2 | kapaa
# Processing Record 46 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | nelson bay
# Processing Record 49 of Set 2 | cayenne
# Processing Record 50 of Set 2 | zhigansk
# Processing Record 1 of Set 3 | faanui
# Processing Record 2 of Set 3 | coruripe
# Processing Record 3 of Set 3 | esperance
# Processing Record 4 of Set 3 | stornoway
# Processing Record 5 of Set 3 | nuuk
# Processing Record 6 of Set 3 | lata
# Processing Record 7 of Set 3 | port pirie
# Processing Record 8 of Set 3 | ponta do sol
# Processing Record 9 of Set 3 | alyangula
# Processing Record 10 of Set 3 | tuktoyaktuk
# Processing Record 11 of Set 3 | takoradi
# Processing Record 12 of Set 3 | pahrump
# Processing Record 13 of Set 3 | isangel
# Processing Record 14 of Set 3 | vila franca do campo
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | victoria
# Processing Record 17 of Set 3 | nouadhibou
# Processing Record 18 of Set 3 | kirakira
# Processing Record 19 of Set 3 | ushuaia
# Processing Record 20 of Set 3 | inirida
# Processing Record 21 of Set 3 | hithadhoo
# Processing Record 22 of Set 3 | aitape
# Processing Record 23 of Set 3 | rio tuba
# Processing Record 24 of Set 3 | bundaberg
# Processing Record 25 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 3 | hamilton
# Processing Record 27 of Set 3 | dikson
# Processing Record 28 of Set 3 | seoul
# Processing Record 29 of Set 3 | natal
# Processing Record 30 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 3 | hirara
# Processing Record 32 of Set 3 | russell
# Processing Record 33 of Set 3 | lander
# Processing Record 34 of Set 3 | guerrero negro
# Processing Record 35 of Set 3 | clyde river
# Processing Record 36 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 37 of Set 3 | asau
# Processing Record 38 of Set 3 | mar del plata
# Processing Record 39 of Set 3 | saint-francois
# Processing Record 40 of Set 3 | potchefstroom
# Processing Record 41 of Set 3 | kuching
# Processing Record 42 of Set 3 | margate
# Processing Record 43 of Set 3 | san jose de guanipa
# Processing Record 44 of Set 3 | moree
# Processing Record 45 of Set 3 | ribeira grande
# Processing Record 46 of Set 3 | east london
# Processing Record 47 of Set 3 | port lincoln
# Processing Record 48 of Set 3 | arraial do cabo
# Processing Record 49 of Set 3 | san cristobal
# Processing Record 50 of Set 3 | rio de janeiro
# Processing Record 1 of Set 4 | pindobacu
# Processing Record 2 of Set 4 | leiyang
# Processing Record 3 of Set 4 | tahoua
# Processing Record 4 of Set 4 | rockland
# Processing Record 5 of Set 4 | havelock
# Processing Record 6 of Set 4 | antofagasta
# Processing Record 7 of Set 4 | kruisfontein
# Processing Record 8 of Set 4 | kodiak
# Processing Record 9 of Set 4 | lamu
# Processing Record 10 of Set 4 | kalabo
# Processing Record 11 of Set 4 | cabo san lucas
# Processing Record 12 of Set 4 | nikolskoye
# Processing Record 13 of Set 4 | sioux lookout
# Processing Record 14 of Set 4 | yerofey pavlovich
# Processing Record 15 of Set 4 | yerbogachen
# Processing Record 16 of Set 4 | maputo
# Processing Record 17 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 4 | waris aliganj
# Processing Record 19 of Set 4 | nogent-le-rotrou
# Processing Record 20 of Set 4 | sangar
# Processing Record 21 of Set 4 | beloha
# Processing Record 22 of Set 4 | pleshanovo
# Processing Record 23 of Set 4 | quatre cocos
# Processing Record 24 of Set 4 | narsaq
# Processing Record 25 of Set 4 | saint john
# Processing Record 26 of Set 4 | zonguldak
# Processing Record 27 of Set 4 | nardaran
# Processing Record 28 of Set 4 | xam nua
# Processing Record 29 of Set 4 | tukrah
# Processing Record 30 of Set 4 | dukat
# Processing Record 31 of Set 4 | geraldton
# Processing Record 32 of Set 4 | linguere
# Processing Record 33 of Set 4 | longyearbyen
# Processing Record 34 of Set 4 | san quintin
# Processing Record 35 of Set 4 | tiksi
# Processing Record 36 of Set 4 | mackenzie
# Processing Record 37 of Set 4 | matara
# Processing Record 38 of Set 4 | hambantota
# Processing Record 39 of Set 4 | sur
# Processing Record 40 of Set 4 | vila velha
# Processing Record 41 of Set 4 | namatanai
# Processing Record 42 of Set 4 | mlimba
# Processing Record 43 of Set 4 | khormuj
# City not found. Skipping...
# Processing Record 44 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 4 | sakaiminato
# Processing Record 46 of Set 4 | yanam
# Processing Record 47 of Set 4 | dire dawa
# Processing Record 48 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 4 | oulainen
# Processing Record 50 of Set 4 | necochea
# Processing Record 1 of Set 5 | thompson
# Processing Record 2 of Set 5 | catamarca
# Processing Record 3 of Set 5 | haradok
# Processing Record 4 of Set 5 | camacha
# Processing Record 5 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 5 | mount pleasant
# Processing Record 7 of Set 5 | paulo ramos
# Processing Record 8 of Set 5 | vardo
# Processing Record 9 of Set 5 | otane
# Processing Record 10 of Set 5 | mahon
# Processing Record 11 of Set 5 | castro
# Processing Record 12 of Set 5 | ilulissat
# Processing Record 13 of Set 5 | tezu
# Processing Record 14 of Set 5 | russas
# Processing Record 15 of Set 5 | ust-maya
# Processing Record 16 of Set 5 | chuy
# Processing Record 17 of Set 5 | lagoa
# Processing Record 18 of Set 5 | hualmay
# Processing Record 19 of Set 5 | khatanga
# Processing Record 20 of Set 5 | hasaki
# Processing Record 21 of Set 5 | akureyri
# Processing Record 22 of Set 5 | gat
# Processing Record 23 of Set 5 | adre
# Processing Record 24 of Set 5 | uyuni
# Processing Record 25 of Set 5 | sitka
# Processing Record 26 of Set 5 | mayumba
# Processing Record 27 of Set 5 | khani
# Processing Record 28 of Set 5 | esperanza
# Processing Record 29 of Set 5 | gorontalo
# Processing Record 30 of Set 5 | mingoyo
# Processing Record 31 of Set 5 | livingston
# Processing Record 32 of Set 5 | troitskaya
# Processing Record 33 of Set 5 | copiapo
# Processing Record 34 of Set 5 | talcahuano
# Processing Record 35 of Set 5 | jalu
# Processing Record 36 of Set 5 | yellowknife
# Processing Record 37 of Set 5 | paucartambo
# City not found. Skipping...
# Processing Record 38 of Set 5 | nanakuli
# Processing Record 39 of Set 5 | easley
# Processing Record 40 of Set 5 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 41 of Set 5 | bintulu
# Processing Record 42 of Set 5 | tambul
# City not found. Skipping...
# Processing Record 43 of Set 5 | sumenep
# Processing Record 44 of Set 5 | saint-pierre
# Processing Record 45 of Set 5 | kazerun
# Processing Record 46 of Set 5 | fairbanks
# Processing Record 47 of Set 5 | tanete
# Processing Record 48 of Set 5 | along
# Processing Record 49 of Set 5 | vanavara
# Processing Record 50 of Set 5 | bilibino
# Processing Record 1 of Set 6 | kano
# Processing Record 2 of Set 6 | katsuura
# Processing Record 3 of Set 6 | kavarna
# Processing Record 4 of Set 6 | touros
# Processing Record 5 of Set 6 | golpayegan
# Processing Record 6 of Set 6 | kurumkan
# Processing Record 7 of Set 6 | tanout
# Processing Record 8 of Set 6 | kloulklubed
# Processing Record 9 of Set 6 | nueve de julio
# Processing Record 10 of Set 6 | chengde
# Processing Record 11 of Set 6 | asosa
# Processing Record 12 of Set 6 | port said
# Processing Record 13 of Set 6 | kodinsk
# Processing Record 14 of Set 6 | sisimiut
# Processing Record 15 of Set 6 | husavik
# Processing Record 16 of Set 6 | ust-nera
# Processing Record 17 of Set 6 | plouzane
# Processing Record 18 of Set 6 | megion
# Processing Record 19 of Set 6 | omboue
# Processing Record 20 of Set 6 | san patricio
# Processing Record 21 of Set 6 | kasongo-lunda
# Processing Record 22 of Set 6 | turmalina
# Processing Record 23 of Set 6 | chokurdakh
# Processing Record 24 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 6 | atar
# Processing Record 26 of Set 6 | atka
# City not found. Skipping...
# Processing Record 27 of Set 6 | aquiraz
# Processing Record 28 of Set 6 | salalah
# Processing Record 29 of Set 6 | kaka
# Processing Record 30 of Set 6 | skibbereen
# Processing Record 31 of Set 6 | itarema
# Processing Record 32 of Set 6 | wajima
# Processing Record 33 of Set 6 | setermoen
# Processing Record 34 of Set 6 | nyagan
# Processing Record 35 of Set 6 | mandalgovi
# Processing Record 36 of Set 6 | gazojak
# Processing Record 37 of Set 6 | asfi
# Processing Record 38 of Set 6 | kununurra
# Processing Record 39 of Set 6 | tomigusuku
# Processing Record 40 of Set 6 | sembe
# Processing Record 41 of Set 6 | sarankhola
# Processing Record 42 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 6 | nome
# Processing Record 44 of Set 6 | kaitangata
# Processing Record 45 of Set 6 | xihe
# Processing Record 46 of Set 6 | kavieng
# Processing Record 47 of Set 6 | lebu
# Processing Record 48 of Set 6 | tazovskiy
# Processing Record 49 of Set 6 | vostok
# Processing Record 50 of Set 6 | estelle
# Processing Record 1 of Set 7 | richards bay
# Processing Record 2 of Set 7 | ballitoville
# Processing Record 3 of Set 7 | crieff
# Processing Record 4 of Set 7 | kahului
# Processing Record 5 of Set 7 | tonantins
# Processing Record 6 of Set 7 | basoko
# Processing Record 7 of Set 7 | panixtlahuaca
# City not found. Skipping...
# Processing Record 8 of Set 7 | amurzet
# Processing Record 9 of Set 7 | kwinana
# Processing Record 10 of Set 7 | mahebourg
# Processing Record 11 of Set 7 | bam
# Processing Record 12 of Set 7 | coihaique
# Processing Record 13 of Set 7 | navan
# Processing Record 14 of Set 7 | komsomolskiy
# Processing Record 15 of Set 7 | moron
# Processing Record 16 of Set 7 | novoagansk
# Processing Record 17 of Set 7 | swan hill
# Processing Record 18 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 7 | visby
# Processing Record 20 of Set 7 | tallahassee
# Processing Record 21 of Set 7 | hovd
# Processing Record 22 of Set 7 | cividale del friuli
# Processing Record 23 of Set 7 | portland
# Processing Record 24 of Set 7 | rocha
# Processing Record 25 of Set 7 | broome
# Processing Record 26 of Set 7 | klaksvik
# Processing Record 27 of Set 7 | requena
# Processing Record 28 of Set 7 | vung tau
# Processing Record 29 of Set 7 | sarangani
# Processing Record 30 of Set 7 | mexico
# Processing Record 31 of Set 7 | port hedland
# Processing Record 32 of Set 7 | cidreira
# Processing Record 33 of Set 7 | cherskiy
# Processing Record 34 of Set 7 | oloron-sainte-marie
# Processing Record 35 of Set 7 | bay roberts
# Processing Record 36 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 7 | bambous virieux
# Processing Record 38 of Set 7 | port hardy
# Processing Record 39 of Set 7 | huarmey
# Processing Record 40 of Set 7 | yulara
# Processing Record 41 of Set 7 | nanortalik
# Processing Record 42 of Set 7 | alta floresta
# Processing Record 43 of Set 7 | lavrentiya
# Processing Record 44 of Set 7 | te horo
# Processing Record 45 of Set 7 | hakkari
# Processing Record 46 of Set 7 | nantucket
# Processing Record 47 of Set 7 | moerai
# Processing Record 48 of Set 7 | juegang
# Processing Record 49 of Set 7 | bogorodskoye
# Processing Record 50 of Set 7 | bo phloi
# Processing Record 1 of Set 8 | ancud
# Processing Record 2 of Set 8 | pangkalanbuun
# Processing Record 3 of Set 8 | magdagachi
# Processing Record 4 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 5 of Set 8 | rosarito
# Processing Record 6 of Set 8 | sawtell
# Processing Record 7 of Set 8 | micheweni
# Processing Record 8 of Set 8 | sechura
# Processing Record 9 of Set 8 | dodge city
# Processing Record 10 of Set 8 | izumo
# Processing Record 11 of Set 8 | meiganga
# Processing Record 12 of Set 8 | escalerillas
# Processing Record 13 of Set 8 | agalatovo
# Processing Record 14 of Set 8 | umm jarr
# City not found. Skipping...
# Processing Record 15 of Set 8 | garissa
# Processing Record 16 of Set 8 | grakhovo
# Processing Record 17 of Set 8 | santa maria
# Processing Record 18 of Set 8 | channel-port aux basques
# Processing Record 19 of Set 8 | maarianhamina
# Processing Record 20 of Set 8 | carballo
# Processing Record 21 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 23 of Set 8 | derzhavinsk
# Processing Record 24 of Set 8 | srednekolymsk
# Processing Record 25 of Set 8 | ayios nikolaos
# Processing Record 26 of Set 8 | kamoke
# Processing Record 27 of Set 8 | salinopolis
# Processing Record 28 of Set 8 | balabac
# Processing Record 29 of Set 8 | buin
# Processing Record 30 of Set 8 | saldanha
# Processing Record 31 of Set 8 | monticello
# Processing Record 32 of Set 8 | mount gambier
# Processing Record 33 of Set 8 | proletariy
# Processing Record 34 of Set 8 | tongliao
# Processing Record 35 of Set 8 | aakirkeby
# City not found. Skipping...
# Processing Record 36 of Set 8 | lazaro cardenas
# Processing Record 37 of Set 8 | havre-saint-pierre
# Processing Record 38 of Set 8 | cabo rojo
# Processing Record 39 of Set 8 | talnakh
# Processing Record 40 of Set 8 | murgab
# Processing Record 41 of Set 8 | fonte boa
# Processing Record 42 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 8 | kralendijk
# Processing Record 44 of Set 8 | codrington
# Processing Record 45 of Set 8 | benguela
# Processing Record 46 of Set 8 | ca mau
# Processing Record 47 of Set 8 | yanggu
# Processing Record 48 of Set 8 | astana
# Processing Record 49 of Set 8 | pokrovka
# Processing Record 50 of Set 8 | mangrol
# Processing Record 1 of Set 9 | karratha
# Processing Record 2 of Set 9 | beringovskiy
# Processing Record 3 of Set 9 | narasannapeta
# Processing Record 4 of Set 9 | lethem
# Processing Record 5 of Set 9 | korla
# Processing Record 6 of Set 9 | brae
# Processing Record 7 of Set 9 | gucheng
# Processing Record 8 of Set 9 | jiuquan
# Processing Record 9 of Set 9 | tokzar
# City not found. Skipping...
# Processing Record 10 of Set 9 | anadyr
# Processing Record 11 of Set 9 | flin flon
# Processing Record 12 of Set 9 | vittoria
# Processing Record 13 of Set 9 | resende
# Processing Record 14 of Set 9 | kidal
# Processing Record 15 of Set 9 | muros
# Processing Record 16 of Set 9 | kampot
# Processing Record 17 of Set 9 | norsup
# Processing Record 18 of Set 9 | lincoln
# Processing Record 19 of Set 9 | rudnogorsk
# Processing Record 20 of Set 9 | huambo
# Processing Record 21 of Set 9 | jijiga
# Processing Record 22 of Set 9 | tsentralnyy
# City not found. Skipping...
# Processing Record 23 of Set 9 | bubaque
# Processing Record 24 of Set 9 | ziro
# Processing Record 25 of Set 9 | pochutla
# Processing Record 26 of Set 9 | onguday
# Processing Record 27 of Set 9 | aguimes
# Processing Record 28 of Set 9 | ostrovnoy
# Processing Record 29 of Set 9 | abbotsford
# Processing Record 30 of Set 9 | angoche
# Processing Record 31 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 32 of Set 9 | kiunga
# Processing Record 33 of Set 9 | belmonte
# Processing Record 34 of Set 9 | peace river
# Processing Record 35 of Set 9 | emerald
# Processing Record 36 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 37 of Set 9 | amahai
# Processing Record 38 of Set 9 | fare
# Processing Record 39 of Set 9 | kabinda
# Processing Record 40 of Set 9 | andenes
# Processing Record 41 of Set 9 | otradnoye
# Processing Record 42 of Set 9 | meulaboh
# Processing Record 43 of Set 9 | marawi
# Processing Record 44 of Set 9 | curuca
# Processing Record 45 of Set 9 | marzuq
# Processing Record 46 of Set 9 | ribas do rio pardo
# Processing Record 47 of Set 9 | lasa
# Processing Record 48 of Set 9 | tibacuy
# Processing Record 49 of Set 9 | inverell
# Processing Record 50 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 1 of Set 10 | tromso
# Processing Record 2 of Set 10 | fukue
# Processing Record 3 of Set 10 | norwich
# Processing Record 4 of Set 10 | shanghai
# Processing Record 5 of Set 10 | coahuayana
# Processing Record 6 of Set 10 | san julian
# Processing Record 7 of Set 10 | ahipara
# Processing Record 8 of Set 10 | morki
# Processing Record 9 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 10 | bykovo
# Processing Record 11 of Set 10 | vestmannaeyjar
# Processing Record 12 of Set 10 | canitas
# City not found. Skipping...
# Processing Record 13 of Set 10 | gamba
# Processing Record 14 of Set 10 | kudat
# Processing Record 15 of Set 10 | ambulu
# Processing Record 16 of Set 10 | naze
# Processing Record 17 of Set 10 | gimli
# Processing Record 18 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 10 | kumeny
# Processing Record 20 of Set 10 | lerwick
# Processing Record 21 of Set 10 | tecoanapa
# Processing Record 22 of Set 10 | cullinan
# Processing Record 23 of Set 10 | berani
# Processing Record 24 of Set 10 | ossora
# Processing Record 25 of Set 10 | claveria
# Processing Record 26 of Set 10 | lompoc
# Processing Record 27 of Set 10 | rantepao
# Processing Record 28 of Set 10 | norrtalje
# Processing Record 29 of Set 10 | tahta
# Processing Record 30 of Set 10 | norman wells
# Processing Record 31 of Set 10 | jiwani
# Processing Record 32 of Set 10 | togur
# Processing Record 33 of Set 10 | aksaray
# Processing Record 34 of Set 10 | pinawa
# Processing Record 35 of Set 10 | anaconda
# Processing Record 36 of Set 10 | half moon bay
# Processing Record 37 of Set 10 | cabra
# Processing Record 38 of Set 10 | paramirim
# Processing Record 39 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 40 of Set 10 | dwarka
# Processing Record 41 of Set 10 | surab
# Processing Record 42 of Set 10 | antalaha
# Processing Record 43 of Set 10 | kawalu
# Processing Record 44 of Set 10 | rabo de peixe
# Processing Record 45 of Set 10 | robertsport
# Processing Record 46 of Set 10 | porto murtinho
# Processing Record 47 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 48 of Set 10 | sorland
# Processing Record 49 of Set 10 | okhotsk
# Processing Record 50 of Set 10 | nevsehir
# Processing Record 1 of Set 11 | mehamn
# Processing Record 2 of Set 11 | say
# Processing Record 3 of Set 11 | grindavik
# Processing Record 4 of Set 11 | puyang
# Processing Record 5 of Set 11 | santiago de cao
# Processing Record 6 of Set 11 | yako
# Processing Record 7 of Set 11 | neiafu
# Processing Record 8 of Set 11 | kavaratti
# Processing Record 9 of Set 11 | lancaster
# Processing Record 10 of Set 11 | laguna
# Processing Record 11 of Set 11 | jizan
# Processing Record 12 of Set 11 | lakhnadon
# Processing Record 13 of Set 11 | mirabad
# Processing Record 14 of Set 11 | erzincan
# Processing Record 15 of Set 11 | steubenville
# Processing Record 16 of Set 11 | chicama
# Processing Record 17 of Set 11 | sao joao da barra
# Processing Record 18 of Set 11 | nieuw amsterdam
# Processing Record 19 of Set 11 | santa cruz
# Processing Record 20 of Set 11 | sao miguel do araguaia
# Processing Record 21 of Set 11 | la ronge
# Processing Record 22 of Set 11 | west plains
# Processing Record 23 of Set 11 | saint george
# Processing Record 24 of Set 11 | marfino
# Processing Record 25 of Set 11 | yining
# Processing Record 26 of Set 11 | wanning
# Processing Record 27 of Set 11 | aswan
# Processing Record 28 of Set 11 | vieques
# Processing Record 29 of Set 11 | jawhar
# Processing Record 30 of Set 11 | sokoni
# Processing Record 31 of Set 11 | bathsheba
# Processing Record 32 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 11 | bor
# Processing Record 34 of Set 11 | ikongo
# Processing Record 35 of Set 11 | takaungu
# Processing Record 36 of Set 11 | berlevag
# Processing Record 37 of Set 11 | tiznit
# Processing Record 38 of Set 11 | jucuaran
# Processing Record 39 of Set 11 | charters towers
# Processing Record 40 of Set 11 | los llanos de aridane
# Processing Record 41 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 11 | sesheke
# Processing Record 43 of Set 11 | marathon
# Processing Record 44 of Set 11 | beckley
# Processing Record 45 of Set 11 | svetlaya
# Processing Record 46 of Set 11 | belyy yar
# Processing Record 47 of Set 11 | namwala
# Processing Record 48 of Set 11 | qui nhon
# Processing Record 49 of Set 11 | tilichiki
# Processing Record 50 of Set 11 | vega de alatorre
# Processing Record 1 of Set 12 | kiri buru
# Processing Record 2 of Set 12 | caravelas
# Processing Record 3 of Set 12 | calama
# Processing Record 4 of Set 12 | raudeberg
# Processing Record 5 of Set 12 | lengshuitan
# Processing Record 6 of Set 12 | swan river
# Processing Record 7 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 12 | westport
# Processing Record 9 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 10 of Set 12 | ucluelet
# Processing Record 11 of Set 12 | mayo
# Processing Record 12 of Set 12 | teahupoo
# Processing Record 13 of Set 12 | tommot
# Processing Record 14 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 15 of Set 12 | shieli
# Processing Record 16 of Set 12 | poum
# Processing Record 17 of Set 12 | marsa matruh
# Processing Record 18 of Set 12 | gejiu
# Processing Record 19 of Set 12 | damietta
# Processing Record 20 of Set 12 | ketchikan
# Processing Record 21 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 22 of Set 12 | tinongan
# Processing Record 23 of Set 12 | segou
# Processing Record 24 of Set 12 | navalmoral de la mata
# Processing Record 25 of Set 12 | kuusamo
# Processing Record 26 of Set 12 | college
# Processing Record 27 of Set 12 | grand gaube
# Processing Record 28 of Set 12 | urumqi
# Processing Record 29 of Set 12 | kutum
# Processing Record 30 of Set 12 | karamken
# City not found. Skipping...
# Processing Record 31 of Set 12 | laje
# Processing Record 32 of Set 12 | axixa do tocantins
# City not found. Skipping...
# Processing Record 33 of Set 12 | baghdad
# Processing Record 34 of Set 12 | puerto suarez
# Processing Record 35 of Set 12 | salta
# Processing Record 36 of Set 12 | hobyo
# Processing Record 37 of Set 12 | ciudad real
# Processing Record 38 of Set 12 | thayetmyo
# Processing Record 39 of Set 12 | dickinson
# Processing Record 40 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 12 | yendi
# Processing Record 42 of Set 12 | keuruu
# Processing Record 43 of Set 12 | saurimo
# Processing Record 44 of Set 12 | katobu
# Processing Record 45 of Set 12 | karangampel
# Processing Record 46 of Set 12 | gonbad-e qabus
# Processing Record 47 of Set 12 | baft
# Processing Record 48 of Set 12 | koryazhma
# Processing Record 49 of Set 12 | sarkand
# Processing Record 50 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 13 | cangzhou
# Processing Record 2 of Set 13 | roma
# Processing Record 3 of Set 13 | vallenar
# Processing Record 4 of Set 13 | pafos
# Processing Record 5 of Set 13 | cap malheureux
# Processing Record 6 of Set 13 | ahuimanu
# Processing Record 7 of Set 13 | wahiawa
# Processing Record 8 of Set 13 | marantao
# Processing Record 9 of Set 13 | saint-joseph
# Processing Record 10 of Set 13 | lekoni
# Processing Record 11 of Set 13 | roblin
# Processing Record 12 of Set 13 | davila
# Processing Record 13 of Set 13 | cumbitara
# Processing Record 14 of Set 13 | hengyang
# Processing Record 15 of Set 13 | tainan
# Processing Record 16 of Set 13 | tautira
# Processing Record 17 of Set 13 | yashkino
# Processing Record 18 of Set 13 | kamenka
# Processing Record 19 of Set 13 | krasnyy chikoy
# Processing Record 20 of Set 13 | qax
# Processing Record 21 of Set 13 | berkak
# Processing Record 22 of Set 13 | jian
# Processing Record 23 of Set 13 | mouzouras
# Processing Record 24 of Set 13 | alpena
# Processing Record 25 of Set 13 | cazones
# Processing Record 26 of Set 13 | palmer
# Processing Record 27 of Set 13 | lahat
# Processing Record 28 of Set 13 | pravda
# Processing Record 29 of Set 13 | south lake tahoe
# Processing Record 30 of Set 13 | sakassou
# Processing Record 31 of Set 13 | lalomanu
# City not found. Skipping...
# Processing Record 32 of Set 13 | kaeo
# Processing Record 33 of Set 13 | kerteh
# City not found. Skipping...
# Processing Record 34 of Set 13 | camapua
# Processing Record 35 of Set 13 | la rioja
# Processing Record 36 of Set 13 | chahuites
# Processing Record 37 of Set 13 | thinadhoo
# Processing Record 38 of Set 13 | baker city
# Processing Record 39 of Set 13 | alofi
# Processing Record 40 of Set 13 | bajo baudo
# City not found. Skipping...
# Processing Record 41 of Set 13 | karwar
# Processing Record 42 of Set 13 | puerto madryn
# Processing Record 43 of Set 13 | kirensk
# Processing Record 44 of Set 13 | sao jose da coroa grande
# Processing Record 45 of Set 13 | axim
# Processing Record 46 of Set 13 | myaundzha
# Processing Record 47 of Set 13 | bilma
# Processing Record 48 of Set 13 | dunedin
# Processing Record 49 of Set 13 | konstantinovsk
# Processing Record 50 of Set 13 | sao felix do xingu
# Processing Record 1 of Set 14 | lubumbashi
# Processing Record 2 of Set 14 | huilong
# Processing Record 3 of Set 14 | paracuru
# Processing Record 4 of Set 14 | constitucion
# Processing Record 5 of Set 14 | dubbo
# Processing Record 6 of Set 14 | port hueneme
# Processing Record 7 of Set 14 | manokwari
# Processing Record 8 of Set 14 | nikolsk
# Processing Record 9 of Set 14 | banda aceh
# Processing Record 10 of Set 14 | cumberland
# Processing Record 11 of Set 14 | wukari
# Processing Record 12 of Set 14 | podor
# Processing Record 13 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 14 of Set 14 | le mars
# Processing Record 15 of Set 14 | aksum
# Processing Record 16 of Set 14 | peski
# Processing Record 17 of Set 14 | sao geraldo do araguaia
# Processing Record 18 of Set 14 | ayios kirikos
# City not found. Skipping...
# Processing Record 19 of Set 14 | roebourne
# Processing Record 20 of Set 14 | auki
# Processing Record 21 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 22 of Set 14 | nyandoma
# Processing Record 23 of Set 14 | carangola
# Processing Record 24 of Set 14 | champerico
# Processing Record 25 of Set 14 | bandarbeyla
# Processing Record 26 of Set 14 | hailar
# Processing Record 27 of Set 14 | porto walter
# Processing Record 28 of Set 14 | turukhansk
# Processing Record 29 of Set 14 | lerum
# Processing Record 30 of Set 14 | maku
# Processing Record 31 of Set 14 | buenos aires
# Processing Record 32 of Set 14 | hay river
# Processing Record 33 of Set 14 | begoro
# Processing Record 34 of Set 14 | massakory
# Processing Record 35 of Set 14 | celestun
# Processing Record 36 of Set 14 | yar-sale
# Processing Record 37 of Set 14 | mattru
# Processing Record 38 of Set 14 | paramonga
# Processing Record 39 of Set 14 | hohhot
# Processing Record 40 of Set 14 | ampanihy
# Processing Record 41 of Set 14 | bonavista
# Processing Record 42 of Set 14 | tura
# Processing Record 43 of Set 14 | edson
# Processing Record 44 of Set 14 | artyom
# Processing Record 45 of Set 14 | mogadishu
# Processing Record 46 of Set 14 | pacifica
# Processing Record 47 of Set 14 | diebougou
# Processing Record 48 of Set 14 | senno
# Processing Record 49 of Set 14 | bayanday
# Processing Record 50 of Set 14 | troy
# Processing Record 1 of Set 15 | matagami
# Processing Record 2 of Set 15 | muromtsevo
# Processing Record 3 of Set 15 | gizo
# Processing Record 4 of Set 15 | coari
# Processing Record 5 of Set 15 | kelamangalam
# Processing Record 6 of Set 15 | ereymentau
# Processing Record 7 of Set 15 | kalmunai
# Processing Record 8 of Set 15 | alibag
# Processing Record 9 of Set 15 | smithers
# Processing Record 10 of Set 15 | kilis
# Processing Record 11 of Set 15 | praia da vitoria
# Processing Record 12 of Set 15 | yumen
# Processing Record 13 of Set 15 | comodoro rivadavia
# Processing Record 14 of Set 15 | nhulunbuy
# Processing Record 15 of Set 15 | mount isa
# Processing Record 16 of Set 15 | traralgon
# Processing Record 17 of Set 15 | shimoda
# Processing Record 18 of Set 15 | lipin bor
# Processing Record 19 of Set 15 | jamalpur
# Processing Record 20 of Set 15 | lalmohan
# Processing Record 21 of Set 15 | gwembe
# Processing Record 22 of Set 15 | nossa senhora das dores
# Processing Record 23 of Set 15 | skovorodino
# Processing Record 24 of Set 15 | baykit
# Processing Record 25 of Set 15 | imbituba
# Processing Record 26 of Set 15 | ust-tsilma
# Processing Record 27 of Set 15 | sept-iles
# Processing Record 28 of Set 15 | labuhan
# Processing Record 29 of Set 15 | vitim
# Processing Record 30 of Set 15 | tupik
# Processing Record 31 of Set 15 | kanadey
# Processing Record 32 of Set 15 | waipawa
# Processing Record 33 of Set 15 | garowe
# Processing Record 34 of Set 15 | rodrigues alves
# Processing Record 35 of Set 15 | padang
# -----------------------------
#    Data Retrieval Complete
# -----------------------------

# %%
# Converting the array of dictionaries to dataframe
city_data_df = pd.DataFrame(city_data)

# %%
# Check & clean up columns
print(city_data_df.columns)

new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

city_data_df = city_data_df[new_column_order]

print(city_data_df.dtypes)
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create csv
output_data_file = "Resources/city_database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
